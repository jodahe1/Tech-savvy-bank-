# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data  = pd.read_excel("./data/Apollo android review data.xlsx",sheet_name="apollo - sentiment_analysis_apo")

# %%
# Total number of reviews
total_reviews = len(data)
print(f"Total number of reviews: {total_reviews}")
# Out:
# Total number of reviews: 100

# %%
# Distribution of scores
plt.figure(figsize=(8, 6))
sns.countplot(data=data, x='score')
plt.title('Distribution of Scores')
plt.show()

# %%
#  Likes distribution
plt.figure(figsize=(8, 6))
sns.histplot(data=data, x='👍', bins=20)
plt.title('Distribution of Likes')
plt.show()
# Out:
# c:\Users\huawei\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\huawei\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128077 (\N{THUMBS UP SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#  Review creation timeline
data['at'] = pd.to_datetime(data['at'])
plt.figure(figsize=(12, 6))
sns.countplot(data=data, x=data['at'].dt.date)
plt.xticks(rotation=90)
plt.title('Review Creation Timeline')
plt.show()

# %%
#  Keyword analysis
print("Top 10 most frequent keywords:")
print(data['Keywords'].value_counts().head(10))
# Out:
# Top 10 most frequent keywords:
# Keywords
# good                        16
# best                         8
# like                         5
# account                      3
# otp                          2
# problem                      1
# authentication               1
# working                      1
# money, deposit, withdraw     1
# happy                        1
# Name: count, dtype: int64

# %%
#  User engagement
avg_likes_per_user = data.groupby('userName')['👍'].mean()
print(f"Average likes per user: {avg_likes_per_user.mean():.2f}")
# Out:
# Average likes per user: 9.16

# %%
#  Reply rate
reply_rate = data['replyContent'].notna().mean() * 100
print(f"Reply rate: {reply_rate:.2f}%")
# Out:
# Reply rate: 0.00%

# %%
#  Insight analysis
print("Top 10 most frequent insights:")
print(data['Insight'].value_counts().head(10))
# Out:
# Top 10 most frequent insights:
# Insight
# No significant influential words    37
# Influential words: Good              8
# Influential words: Best              5
# Influential words: good              4
# Influential words: Nice              4
# Influential words: Best, best        2
# Influential words: nice              2
# Influential words: Very, good        2
# Influential words: fails             1
# Influential words: Nice, mean        1
# Name: count, dtype: int64

# %%
top_10_insights = data['Insight'].value_counts().head(10)

plt.bar(top_10_insights.index, top_10_insights.values)
plt.xlabel("Insights")
plt.ylabel("Frequency")
plt.title("Top 10 Most Frequent Insights")
plt.xticks(rotation=90)
plt.show()
